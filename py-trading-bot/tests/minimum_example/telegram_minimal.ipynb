# %% [markdown]
# In this example, we will build a Telegram bot that sends a signal once any Bollinger Band has been crossed. We will periodically query for the latest OHLCV data of the selected cryptocurrencies and append this data to our data pool. Additionally to receiving signals, any Telegram user can join the group and ask the bot to provide him with the current information. If the price change is higher than some number of standard deviations from the mean, while crossing the band, the bot sends a funny GIF.

# %%
import pandas as pd
import vectorbtpro as vbt
import logging

# %%
logging.basicConfig(format='%(asctime)s - %(name)s - %(levelname)s - %(message)s', level=logging.INFO)
logger = logging.getLogger(__name__)

# %%
telegram_bot = vbt.TelegramBot(token="5847483360:AAG56QANUMfVwmhZaFrUjeOO00GsnzqRbzM")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File /media/maxime/Gros/Progra/Anaconda/envs/tradingbot312/lib/python3.12/site-packages/vectorbtpro/utils/telegram.py:1190, in TelegramBot.start(self, close_loop, stop_signals, **kwargs)
#    1189     updater_coroutine.close()
# -> 1190     raise exc
#    1191 finally:
#
# File /media/maxime/Gros/Progra/Anaconda/envs/tradingbot312/lib/python3.12/site-packages/vectorbtpro/utils/telegram.py:1179, in TelegramBot.start(self, close_loop, stop_signals, **kwargs)
#    1178 try:
# -> 1179     self.loop.run_until_complete(self.application.initialize())
#    1180     if self.application.post_init is not None:
#
# File /media/maxime/Gros/Progra/Anaconda/envs/tradingbot312/lib/python3.12/asyncio/base_events.py:667, in BaseEventLoop.run_until_complete(self, future)
#     666 self._check_closed()
# --> 667 self._check_running()
#     669 new_task = not futures.isfuture(future)
#
# File /media/maxime/Gros/Progra/Anaconda/envs/tradingbot312/lib/python3.12/asyncio/base_events.py:626, in BaseEventLoop._check_running(self)
#     625 if self.is_running():
# --> 626     raise RuntimeError('This event loop is already running')
#     627 if events._get_running_loop() is not None:
#
# RuntimeError: This event loop is already running
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[19], line 2
#       1 telegram_bot = vbt.TelegramBot(token="5847483360:AAG56QANUMfVwmhZaFrUjeOO00GsnzqRbzM")
# ----> 2 telegram_bot.start()
#
# File /media/maxime/Gros/Progra/Anaconda/envs/tradingbot312/lib/python3.12/site-packages/vectorbtpro/utils/telegram.py:1192, in TelegramBot.start(self, close_loop, stop_signals, **kwargs)
#    1190     raise exc
#    1191 finally:
# -> 1192     self.stop(close_loop=close_loop)
#
# File /media/maxime/Gros/Progra/Anaconda/envs/tradingbot312/lib/python3.12/site-packages/vectorbtpro/utils/telegram.py:1206, in TelegramBot.stop(self, close_loop)
#    1204     raise RuntimeError("There is no event loop running this Application")
#    1205 try:
# -> 1206     self.loop.run_until_complete(self.pre_stop_callback())
#    1207     if self.application.updater.running:
#    1208         self.loop.run_until_complete(self.application.updater.stop())
#
# File /media/maxime/Gros/Progra/Anaconda/envs/tradingbot312/lib/python3.12/asyncio/base_events.py:667, in BaseEventLoop.run_until_complete(self, future)
#     656 """Run until the Future is done.
#     657
#     658 If the argument is a coroutine, it is wrapped in a Task.
#    (...)    664 Return the Future's result, or raise its exception.
#     665 """
#     666 self._check_closed()
# --> 667 self._check_running()
#     669 new_task = not futures.isfuture(future)
#     670 future = tasks.ensure_future(future, loop=self)
#
# File /media/maxime/Gros/Progra/Anaconda/envs/tradingbot312/lib/python3.12/asyncio/base_events.py:626, in BaseEventLoop._check_running(self)
#     624 def _check_running(self):
#     625     if self.is_running():
# --> 626         raise RuntimeError('This event loop is already running')
#     627     if events._get_running_loop() is not None:
#     628         raise RuntimeError(
#     629             'Cannot run the event loop while another loop is running')
#
# RuntimeError: This event loop is already running

# %%
telegram_bot.start()

# %%
#if nothing happens, think of making /start in telegram directly
telegram_bot.send_message_to_all("test")
# Out:
# 2023-01-06 20:38:07,842 - vectorbtpro.messaging.telegram - INFO - 5402841128 - Bot: "test"

# %%
telegram_bot.stop()
# Out:
# 2023-01-06 20:38:17,592 - vectorbtpro.messaging.telegram - INFO - Stopping bot
# 2023-01-06 20:38:17,593 - apscheduler.scheduler - INFO - Scheduler has been shut down

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_16343/3628724820.py in <module>
# ----> 1 vbt.TelegramBot()
#
# AttributeError: module 'vectorbt' has no attribute 'TelegramBot'
